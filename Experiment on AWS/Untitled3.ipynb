# %%
experiment - dynamic - lstm - with val loss scheduler - - grad accu false

# %%
# !python main.py
# Out:
# {'optimizer': {'name': 'adam', 'lr': 0.001, 'final_lr': 1e-06, 'weight_decay': 0}, 'train': {'model_test_run': False, 'weighted_loss_fn': True, 'epoch': 2000, 'batch_size': 16, 'save_model': True, 'log_loss': True, 'test_step': 1, 'reproducible': True, 'seed': 2023, 'tensorboard': False, 'ssl': False, 'gradient_accumulation': False, 'accumulation_steps': 4, 'early_stop': False, 'parameter_class_weights_path': './datasets/sequential/aug/parameters/param.pkl', 'parameter_label_mapping_path': './datasets/sequential/aug/parameters/label_mapping.pkl'}, 'test': {'metrics': ['recall', 'precision'], 'k': [1, 2, 3], 'batch_size': 16}, 'data': {'type': 'sequential', 'name': 'aug', 'seq_aug': False, 'dynamic_context_window_length': 100, 'user_num': 4426, 'item_num': 28, 'max_context_length': 100, 'dynamic_context_feat_num': 18, 'static_context_feat_num': 3, 'static_context_max': [1, 1, 1]}, 'model': {'name': 'cl4srec', 'context_encoder': 'lstm', 'interaction_encoder': 'sasrec', 'dropout_rate': 
# ...

# %%
# !nvidia-smi
# Out:
# Fri Mar  8 12:05:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.12             Driver Version: 535.104.12   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       On  | 00000000:00:1E.0 Off |                    0 |
# | N/A   46C    P0              61W /  70W |   3193MiB / 15360MiB |     97%      Default |
# |                                         |                      |                  N/A |
# ...
